# %% [markdown]
# ### 학습목표
# - 시각화 패키치 matplotlib
# - 서브 패키지 pyplot
# - seaborn
# - 분석된 내용을 시각화
# - Pandas 시각화 기능

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# - line plot : 데이터가 시간, 순서 등에 따라 어떻게 변화하는지를 보여주는 plot

# %%
plt.title('line plot')
plt.plot([1,4,9,16]) # y축
plt.show()

# %%
plt.title('라인 플롯')
plt.plot([10,20,30,40],[1,4,9,16]) # 2차원이면 앞이 x축 뒤가 y축
plt.xlabel('x 라벨')
plt.ylabel('y 라벨')
plt.show()

# %% [markdown]
# - option(color, marker, line style)
# - 약어 -> blue : b red : r / line style -> . , -- 등

# %%
plt.title('라인 플롯')
plt.plot([10,20,30,40],[1,4,9,16],'bs-') # 2차원이면 앞이 x축 뒤가 y축
plt.xlabel('x 라벨')
plt.ylabel('y 라벨')
plt.show()

# %%
from IPython.display import Image
Image('./images/line_style.png')

# %%
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False 
# 그래프 수치에 마이너스가 나올경우 오류 안나게 방지

plt.title('스타일 적용 예')
plt.plot([10,20,30,40],[1,4,9,16],
        c='pink',
        lw=5,ls='--',marker='o',ms=15,mec='skyblue',mew=5,mfc='violet') # 2차원이면 앞이 x축 뒤가 y축
plt.xlabel('x 라벨')
plt.ylabel('y 라벨')
plt.xlim(0,50)
plt.ylim(-10,30)
plt.show()

# %% [markdown]
# - tick(xticks, yticks)

# %%
X = np.linspace(-np.pi,np.pi,256)
Y = np.cos(X)
plt.plot(X,Y)
plt.xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi])
plt.yticks([-1,0,+1]) # 축의 위치/범위를 표현한다
plt.show()

# %%
X = np.linspace(-np.pi,np.pi,256)
Y = np.cos(X)
plt.plot(X,Y)
plt.xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi])
plt.yticks([-1,0,+1]) # 축의 위치를 표현한다
plt.grid(True) # 격자 생성
plt.show()

# %% [markdown]
# - 여러개의 라인 플롯을 그린다면?

# %%
data = np.arange(0,5.0,0.2)
data
plt.title('여러개의 라인 플롯')
plt.plot(data,data,'r--',data,data**2,'b--',data,data**3,'g--')
plt.show()

# %%
plt.title('라인을 겹쳐 그리기')
plt.plot([1,4,9,16],
        c='pink',
        lw=5,ls='--',marker='o',ms=15,mec='skyblue',mew=5,mfc='violet')
plt.plot([9,16,4,1],
        c='orange',
        lw=3,ls='--',marker='s',ms=10,mec='green',mew=5,mfc='c')

# %%
X = np.linspace(-np.pi, np.pi, 256)
Y_C, Y_S =np.cos(X),np.sin(X)
plt.plot(X,Y_C,ls='--',label='cosine')
plt.plot(X,Y_S,ls='--',label='sine')
plt.legend(loc=0) # 이때 loc = 10 은 범례를 센터로 이동시킨다 0~10까지 사용가능

# %% [markdown]
# - matplotlib 그림을 그리는 객체, Figure , Axes, Axis 객체를 포함하고 있다.
# - Figure -> 그림이 그려지는 종이
# - Axes -> 하나의 플롯
# - Axis -> 플롯의 축

# %%
np.random.seed(100)
plt.figure(figsize=(10,2)) # 하나의 그림을 그릴거면 figure을 그리지 않아도됨
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# - subplot(2,1,1) # 2-> 2행 1열 마지막 1은 순서
# - subplot(2,1,2)

# %%
X1 = np.linspace(0.0,5.0)
Y1 = np.cos(2*np.pi*X1)*np.exp(-X1)
print(X1)
print(Y1)
X2 = np.linspace(0.0,2.0)
Y2 = np.cos(2*np.pi*X2)
print(X2)
print(Y2)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]
# [ 1.          0.72367065  0.2320026  -0.25429107 -0.55721991 -0.59913951
#  -0.41280458 -0.10893327  0.17893551  0.34780448  0.35748852  0.23380958
#   0.04690762 -0.12275601 -0.21591812 -0.21241248 -0.13137462 -0.01694367
#   0.08259904  0.1333648   0.12567347  0.0731473   0.00339549 -0.05472957
#  -0.08198104 -0.07402828 -0.04029719  0.00203856  0.03580865  0.05016511
# ...

# %%
axes01 = plt.subplot(2,1,1)
plt.plot(X1,Y1)
plt.title('subplot 01')

axes02 = plt.subplot(2,1,2)
plt.plot(X2,Y2)
plt.title('subplot 02')

plt.tight_layout() # 자동으로 간격을 맞춰주는 역할
plt.show()

# %%
axes01 = plt.subplot(1,2,1)
plt.plot(X1,Y1)
plt.title('subplot 01')

axes02 = plt.subplot(1,2,2)
plt.plot(X2,Y2)
plt.title('subplot 02')

plt.tight_layout() # 자동으로 간격을 맞춰주는 역할
plt.show()

# %% [markdown]
# ### 플롯의 유형
# - line plot
# - scatter plot
# - contour plot
# - surface plot
# - bar plot
# - histogram plot
# - box plot

# %%
# bar plot
# x데이터는 카테고리 값인 경우가 대부분이다
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pylab as plt
# %matplotlib inline

Y = [2,3,1]
X = np.arange(len(Y))

xlabel = ['1등실','2등실','3등실']
plt.title('bar plot')
plt.bar(X,Y)
plt.xticks(X,xlabel)
plt.yticks(sorted(Y))
plt.xlabel('선실 등급')
plt.ylabel('생존자 수')
plt.show()

# %%
Y = [2,3,1]
X = np.arange(len(Y))

xlabel = ['1등실','2등실','3등실']
plt.title('bar plot')
plt.barh(X,Y) # 회전시키고 싶으면 bar가 아닌 barh
plt.yticks(X,xlabel)
plt.xticks(sorted(Y))
plt.ylabel('선실 등급')
plt.xlabel('생존자 수')
plt.show()

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
iris.rename(columns = {iris.columns[0] : 'SL',
                      iris.columns[1] : 'SW',
                      iris.columns[2] : 'PL',
                       iris.columns[3] : 'PW',
                       iris.columns[4] : 'Y'},inplace=True)
# inplce -> 원본에 영향

# %%
iris.head()
# Out:
#     SL   SW   PL   PW       Y
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
iris[['SL','SW']][:5]
# Out:
#     SL   SW
# 0  5.1  3.5
# 1  4.9  3.0
# 2  4.7  3.2
# 3  4.6  3.1
# 4  5.0  3.6

# %%
# 종을 기준으로 그룹화를 하여 각 그룹의 평균을 구해보고
species_mean=iris.groupby(['Y']).mean()
species_mean
# Out:
#                SL     SW     PL     PW
# Y
# setosa      5.006  3.428  1.462  0.246
# versicolor  5.936  2.770  4.260  1.326
# virginica   6.588  2.974  5.552  2.026

# %%
species_mean.columns.name='SP'
species_mean
# Out:
# SP             SL     SW     PL     PW
# Y
# setosa      5.006  3.428  1.462  0.246
# versicolor  5.936  2.770  4.260  1.326
# virginica   6.588  2.974  5.552  2.026

# %%
species_mean.T.plot.bar(rot=0) #rot = 0 은 라벨 회전..?
plt.title('각 변수별 평균')
plt.xlabel('평균')
plt.ylabel('변수')
plt.ylim(0,8)
plt.show()

# %% [markdown]
# - iris boxplot

# %%
iris[['SL','Y']].head()
# Out:
#     SL       Y
# 0  5.1  setosa
# 1  4.9  setosa
# 2  4.7  setosa
# 3  4.6  setosa
# 4  5.0  setosa

# %%
iris[['SL','Y']].boxplot(by='Y')
plt.title('종에 따른 SL boxplot')
plt.xlabel('type')
plt.ylabel('cm')
plt.tight_layout(pad=3) # 제목과 boxplot 이름 사이의 간격을 부여한다
plt.show()

# %%
fig, axes = plt.subplots(nrows=2,ncols=2,figsize=(30,20)) # 틀을 잡는 함수
ax=axes.flatten() # 그림을 그리게 하는 함수 

iris[['SL','Y']].boxplot(by='Y',ax=ax[0])
plt.title('종에 따른 SL boxplot')
plt.xlabel('type')
plt.ylabel('cm')


iris[['SW','Y']].boxplot(by='Y',ax=ax[1])
plt.title('종에 따른 SW boxplot')
plt.xlabel('type')
plt.ylabel('cm')
 

iris[['PL','Y']].boxplot(by='Y',ax=ax[2])
plt.title('종에 따른 PL boxplot')
plt.xlabel('type')
plt.ylabel('cm')


iris[['PW','Y']].boxplot(by='Y',ax=ax[3])
plt.title('종에 따른 PW boxplot')
plt.xlabel('type')
plt.ylabel('cm')
 
    
    
plt.show()

# %%
iris[['SW','Y']].boxplot(by='Y')

# %% [markdown]
# ### car_mpg.xls[실습]

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xls = pd.ExcelFile('./data/car_mpg.xlsx')

# %%
data_df = xls.parse(xls.sheet_names[0]) # 몇번째 sheet 읽을지
data_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
# manufacturer    234 non-null object
# model           234 non-null object
# displ           234 non-null float64
# year            234 non-null int64
# cyl             234 non-null int64
# trans           234 non-null object
# drv             234 non-null object
# cty             234 non-null int64
# hwy             234 non-null int64
# fl              234 non-null object
# class           234 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
data_df['fl'] # 연료의 종류
# Out:
# 1      p
# 2      p
# 3      p
# 4      p
# 5      p
# 6      p
# 7      p
# 8      p
# 9      p
# 10     p
# 11     p
# 12     p
# 13     p
# 14     p
# 15     p
# 16     p
# 17     p
# 18     p
# 19     r
# 20     e
# 21     r
# 22     r
# 23     r
# 24     p
# 25     p
# 26     p
# 27     p
# 28     p
# 29     r
# 30     e
#       ..
# 205    r
# 206    r
# 207    r
# 208    r
# 209    r
# 210    p
# 211    p
# 212    r
# 213    d
# 214    r
# 215    r
# 216    p
# 217    p
# 218    r
# 219    r
# 220    r
# 221    r
# 222    d
# 223    d
# 224    r
# 225    r
# 226    r
# 227    r
# 228    p
# 229    p
# 230    p
# 231    p
# 232    p
# 233    p
# 234    p
# Name: fl, Length: 234, dtype: object

# %%
# 기술통계 값
data_df.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# - 양적자료 : 요약정보에 집계가 되는 컬럼으로 관측된 값이 수치 형태의 속성을 가지는 자료
# - 양적자료의 시각화 boxplot
#
#
# - 질적자료 : 범주 또는 순서 형태의 속성을 가지는 자료로서 도수분포표와 히스토그램으로 데이터의 분포를 확인해야하는 값들

# %%
# 양적자료 -> 배기량, 생산년도, 실런더의 수, 도시연비 ,고속도로연비

# 질적자료 -> 제조사, 변속기 종류, 구동방식, 연료종류, 자동차 종류

data_df.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
# 양적자료의 데이터 분포 확인(boxplot)
data_df.boxplot(['displ','cyl','cty','hwy'])
plt.show()

# %%
data_df['manufacturer'].value_counts()
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# hyundai       14
# subaru        14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# mercury        4
# land rover     4
# lincoln        3
# Name: manufacturer, dtype: int64

# %%
data_df['model'].value_counts()
# Out:
# caravan 2wd               11
# ram 1500 pickup 4wd       10
# jetta                      9
# mustang                    9
# civic                      9
# dakota pickup 4wd          9
# grand cherokee 4wd         8
# impreza awd                8
# a4 quattro                 8
# camry solara               7
# tiburon                    7
# passat                     7
# durango 4wd                7
# camry                      7
# toyota tacoma 4wd          7
# sonata                     7
# a4                         7
# f150 pickup 4wd            7
# explorer 4wd               6
# forester awd               6
# altima                     6
# new beetle                 6
# 4runner 4wd                6
# malibu                     5
# gti                        5
# corolla                    5
# grand prix                 5
# c1500 suburban 2wd         5
# corvette                   5
# k1500 tahoe 4wd            4
# range rover                4
# pathfinder 4wd             4
# ...

# %%
data_df['trans'].value_counts()
# Out:
# auto(l4)      83
# manual(m5)    58
# auto(l5)      39
# manual(m6)    19
# auto(s6)      16
# auto(l6)       6
# auto(av)       5
# auto(s5)       3
# auto(s4)       3
# auto(l3)       2
# Name: trans, dtype: int64

# %%
data_df['displ'].value_counts()
# Out:
# 2.0    21
# 2.5    20
# 4.7    17
# 4.0    15
# 1.8    14
# 2.4    13
# 4.6    11
# 2.8    10
# 3.3     9
# 3.0     8
# 5.7     8
# 2.7     8
# 3.8     8
# 5.4     8
# 3.1     6
# 5.3     6
# 2.2     6
# 1.6     5
# 5.2     5
# 3.5     5
# 3.4     4
# 4.2     4
# 3.9     3
# 3.7     3
# 1.9     3
# 5.0     2
# 6.2     2
# 3.6     2
# 5.9     2
# 4.4     1
# 5.6     1
# 6.5     1
# 7.0     1
# 6.0     1
# 6.1     1
# Name: displ, dtype: int64

# %%
# 자동차 배기량(displ)에 따라 고속도로 연비(hwy)가 다른지를 알아보자
# 배기량이 4이하인 자동차와 5이상인 자동차 중 어떤 자동차의 고속도로 연비가 평균적으로 
# 높은지를 알아보자

displ_lower=data_df[data_df['displ']<=4]
#data_df.query('displ<=4')['hwy'].mean()
displ_upper=data_df[data_df['displ']>=5]
#data_df.query('displ>=5')['hwy'].mean()

print(displ_lower['hwy'].mean())
print(displ_upper['hwy'].mean())
# Out:
# 25.96319018404908
# 18.07894736842105

# %% [markdown]
# - query() : 열을 기준으로 행에 대한 필터링이 가능하다

# %%
query_df = pd.DataFrame(np.random.randint(0,10,size=(10,3)),columns=['col01','col02','col03'])
query_df
# Out:
#    col01  col02  col03
# 0      1      3      2
# 1      3      1      0
# 2      6      5      2
# 3      0      0      9
# 4      1      5      2
# 5      3      6      1
# 6      4      3      1
# 7      4      4      9
# 8      5      6      3
# 9      4      3      7

# %%
query_df.query('col01>2 and col02<5')
# Out:
#    col01  col02  col03
# 1      3      1      0
# 6      4      3      1
# 7      4      4      9
# 9      4      3      7

# %%
# 문제2
# 자동차 제조 회사에 따라 도시 연비가 다른지 알아보려고 한다
# audi와 toyota 중 manufacturer(자동차 제조 회사)의 cty(도시연비)가 평균적으로 더 높은지 알아보시오
question2=data_df[(data_df['manufacturer']=='audi')|(data_df['manufacturer']=='toyota')]
two_mean=question2.groupby('manufacturer').mean()['cty']
# data_df.query('manufacturer=="audi"')['cty'].mean()

question2[['manufacturer','cty']].boxplot(by='manufacturer')


# print(two_mean)
# two_mean.plot.bar(rot=0)
# qustion2=pd.DataFrame(question2)
# question2['cty'].boxplot(by='manufacturer')

# %%
# 문제3
# chevrolet ,ford, honda 자동차의 고속도로 연비 평균을 알아보려고 한다
# 이 회사들의 데이터를 추출한 후 hwy 전체 평균을 확인하시오

question3=data_df[(data_df['manufacturer']=='chevrolet')|(data_df['manufacturer']=='ford')
                 |(data_df['manufacturer']=='honda')]

question3



print(question3.mean())
three_mean=question3.groupby('manufacturer').mean()['hwy']
display(three_mean)
three_mean.plot.bar()
question3[['manufacturer','hwy']].boxplot(by='manufacturer')
# maufac_car = ['chevrolet','ford','honda']
# data_df.query('manufacturer in @maufac_car')['hwy'].mean()
# data_df.query('manufacturer == "chevrolet" or \
#                 manufacturer == "ford" or \
#                  manufacturer == "honda"')['hwy'].mean()
# Out:
# displ       4.245283
# year     2003.415094
# cyl         6.679245
# cty        16.132075
# hwy        22.509434
# dtype: float64
# manufacturer
# chevrolet    21.894737
# ford         19.360000
# honda        32.555556
# Name: hwy, dtype: float64

# %% [markdown]
# - 데이터 전처리 : 연료가격 변수 추가(price_fl)
# - c : 가스 2.35, d : 디젤 2.38, e : 에탄올 2.11 , p : 고급휘발유 2.76, r : 보통휘발유 2.22

# %%
fl_df = pd.DataFrame({
    'fl' : ['c','d','e','p','r'],
    'price_fl' : [2.35,2.38,2.11,2.76,2.22]
})
fl_df
# Out:
#   fl  price_fl
# 0  c      2.35
# 1  d      2.38
# 2  e      2.11
# 3  p      2.76
# 4  r      2.22

# %%
# 연료 가격 프레임을 원본 프레임에 병합

data_fl_merge_df=pd.merge(data_df,fl_df,on='fl',how='inner')
data_fl_merge_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    price_fl
# 0      2.76
# 1      2.76
# 2      2.76
# 3      2.76
# 4      2.76

# %%
# 머지한 데이터 프레임에서 model.fl.price_fl만 추출
data_fl_merge_df[['model','fl','price_fl']]
# data_fl_merge_df.filter(['model','fl','price_fl'])
# Out:
#                    model fl  price_fl
# 0                     a4  p      2.76
# 1                     a4  p      2.76
# 2                     a4  p      2.76
# 3                     a4  p      2.76
# 4                     a4  p      2.76
# 5                     a4  p      2.76
# 6                     a4  p      2.76
# 7             a4 quattro  p      2.76
# 8             a4 quattro  p      2.76
# 9             a4 quattro  p      2.76
# 10            a4 quattro  p      2.76
# 11            a4 quattro  p      2.76
# 12            a4 quattro  p      2.76
# 13            a4 quattro  p      2.76
# 14            a4 quattro  p      2.76
# 15            a6 quattro  p      2.76
# 16            a6 quattro  p      2.76
# 17            a6 quattro  p      2.76
# 18              corvette  p      2.76
# 19              corvette  p      2.76
# 20              corvette  p      2.76
# 21              corvette  p      2.76
# 22              corvette  p      2.76
# 23               mustang  p      2.76
# ...

# %%
# 데이터 전처리 과정에서 결측값 확인하기
data_fl_merge_df.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# class           0
# price_fl        0
# dtype: int64

# %%
# 임의적으로 결측값 처리를 위해서 더미 값을 넣어보도록 하자


# 구동방식(div)별 고속도로 연비(hwy) 평균
data_fl_merge_df.loc[65,'hwy'] = np.nan
data_fl_merge_df.loc[120,'hwy'] = np.nan
data_fl_merge_df.loc[154,'hwy'] = np.nan
data_fl_merge_df.loc[189,'hwy'] = np.nan
data_fl_merge_df.loc[219,'hwy'] = np.nan
data_fl_merge_df.loc[230,'hwy'] = np.nan

# %%
data_fl_merge_df.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             6
# fl              0
# class           0
# price_fl        0
# dtype: int64

# %%
data_fl_merge_df[['drv','hwy']].isna().sum()
# Out:
# drv    0
# hwy    6
# dtype: int64

# %%
data_fl_merge_df['drv'].value_counts()
# Out:
# f    106
# 4    103
# r     25
# Name: drv, dtype: int64

# %%
# hwy 변수의 결측값을 제외하고, 어떤 구동방식과 고속도로평균 연비가 높은지 알아보자

# %%
data_fl_merge_isna_df=data_fl_merge_df[['drv','hwy']].dropna() # 결측치 제거
data_fl_merge_isna_df.info()

data_fl_merge_isna_df.groupby('drv').mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 0 to 233
# Data columns (total 2 columns):
# drv    228 non-null object
# hwy    228 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 5.3+ KB
#            hwy
# drv
# 4    19.174757
# f    27.960000
# r    21.000000

# %%
# 구동방식별 연비평균을 비교하기 위해 막대 그래프로 시각화 해보기

drv_group_df=data_fl_merge_isna_df.groupby('drv').mean()
display(drv_group_df)

drv_group_df.plot.bar(rot=0)
plt.title('구동방식별 연비평균 비교')
plt.xlabel('구동방식')
plt.ylabel('연비')
plt.grid()
# Out:
#            hwy
# drv
# 4    19.174757
# f    27.960000
# r    21.000000

# %%
# 구동방식별 고속도로 도시경비의 평균을 구해보고
# 이를 데이터 프레임으로 만들어서 막대그래프로 시각화
cty_group_df=data_fl_merge_df.groupby('drv').mean()[['cty','hwy']]
display(cty_group_df)

cty_group_df.plot.bar(rot=0)
plt.title('구동방식별 고속도로 도시 연비평균 비교')
plt.xlabel('구동방식')
plt.ylabel('연비')
plt.grid()
# Out:
#            cty        hwy
# drv
# 4    14.330097  19.174757
# f    19.971698  27.960000
# r    14.080000  21.000000

# %%
# 자동차(class) 중에서 어떤 자동차가 가장 많은지 알아보려고 한다.
# 종류별 빈도를 막대그래프로 시각화 
class_count=data_fl_merge_df.groupby('class').size()
class_count=class_count.sort_values(ascending=False)
class_count.plot.bar(rot=0)

plt.title('class 비교')
plt.xlabel('class')
plt.ylabel('count')
# Out:
# Text(0,0.5,'count')

# %%
# 어떤 회사에서 생산한 suv 차종의 도시 연비가 높은지를 알아보려고한다.
# suv 차종을 대상으로 평균 도시연비가 가장 높은 다섯곳을 막대 그래프로 시각화 해보자


mean=data_fl_merge_df[data_fl_merge_df['class']=='suv'].groupby('manufacturer').mean()


mean = mean['cty'].sort_values(ascending=False)[:5]
mean.plot.bar(rot=0)
plt.title('회사별 suv 도시연비 비교')
plt.xlabel('제조사')
plt.ylabel('도시 연비')
# Out:
# Text(0,0.5,'도시 연비')

# %%
# 2020-10-20
# 이상치 정제

# car_mpg 데이터에서 구동방식별 고속도로 연비 평균과 도시연비 평균을 극단치를 제외하고 확인
# 각 연비별 이상치 확인 boxplot()


outlier_df = data_df.filter(['hwy','cty'])
outlier_df.boxplot()
plt.show()

# %%
# 3사분위에 대한 정보를 알아보기
quantile75 = outlier_df.quantile(q=0.75)
quantile75
# Out:
# hwy    27.0
# cty    19.0
# Name: 0.75, dtype: float64

# %%
# 1사분위에 대한 정보를 알아보기
quantile25 = outlier_df.quantile(q=0.25)
quantile25
# Out:
# hwy    18.0
# cty    14.0
# Name: 0.25, dtype: float64

# %%
# IQR(3사분위 수  - 1사분위수의 차)
iqr = quantile75 - quantile25
iqr
# Out:
# hwy    9.0
# cty    5.0
# dtype: float64

# %%
# 최저 한계치(lower fence)
lower_fence = quantile25 - 1.5 * iqr
print('lower_fence\n', lower_fence)

# 최고 한계치(upper fence)
upper_fence = quantile75 + 1.5 * iqr
print('upper_fence\n', upper_fence)
# Out:
# lower_fence
#  hwy    4.5
# cty    6.5
# dtype: float64
# upper_fence
#  hwy    40.5
# cty    26.5
# dtype: float64

# %%
# 극단치 경계 값 (아래 수평 선)

lower_outlier=outlier_df[outlier_df > lower_fence].min()
lower_outlier
# Out:
# hwy    12
# cty     9
# dtype: int64

# %%
# 극단치 경계 값 (위 수평 선)
upper_outlier=outlier_df[outlier_df < upper_fence].max()
upper_outlier
# Out:
# hwy    37.0
# cty    26.0
# dtype: float64

# %%
# 이상치를 결측값으로 변경
# 고속도로 연비의 이상치 데이터 추출
hwy_outlier_df = data_df.query('hwy > '+str(upper_outlier['hwy']))
hwy_outlier_df
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 213   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 223   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 213     compact
# 222  subcompact
# 223  subcompact

# %%
# 도시 연비의 이상치 데이터 추출
cty_outlier_df = data_df.query('cty > '+str(upper_outlier['cty']))
cty_outlier_df
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 100        honda       civic    1.6  1999    4  manual(m5)   f   28   33  r
# 197       toyota     corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 213   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 223   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 100  subcompact
# 197     compact
# 213     compact
# 222  subcompact
# 223  subcompact

# %%
# copy() - 데이터 전처리를 위해 원본데이터 복사
outlier_clean_df = data_df.copy()
outlier_clean_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# hwy 연비에 대한 이상치를 결측값으로 변경
for idx in hwy_outlier_df.index :
    #print(idx)
    outlier_clean_df.loc[idx,'hwy'] = np.nan
outlier_clean_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty   hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18  29.0  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21  29.0  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20  31.0  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21  30.0  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16  26.0  p  compact

# %%
# cty 연비에 대한 이상치를 결측값으로 변경
for idx in cty_outlier_df.index :
    #print(idx)
    outlier_clean_df.loc[idx,'cty'] = np.nan
outlier_clean_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv   cty   hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f  18.0  29.0  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f  21.0  29.0  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f  20.0  31.0  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f  21.0  30.0  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f  16.0  26.0  p  compact

# %%
# 결측치 확인
outlier_clean_df.filter(['cty','hwy']).isna().sum()
# Out:
# cty    5
# hwy    3
# dtype: int64

# %%
# 결측값 제시한 구동방식별 고속도로, 도시 연비 평균
drv_mean_df = outlier_clean_df.filter(['drv','hwy','cty']).dropna().groupby('drv').mean()
drv_mean_df
# Out:
#            hwy        cty
# drv
# 4    19.174757  14.330097
# f    27.584158  19.445545
# r    21.000000  14.080000

# %%
# 시각화
drv_mean_df.plot.bar(rot=0)
plt.title('이상치 제거 후 고속도로, 도시 평균 연비 비교')
plt.xlabel('구동방식')
plt.ylabel('평균연비')
# Out:
# Text(0,0.5,'평균연비')

# %%
drv_mean_df = outlier_clean_df.filter(['hwy','cty'])
drv_mean_df.boxplot()
