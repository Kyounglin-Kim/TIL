# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
from urllib.error import URLError

# %%
# 오픈을 할때 예외처리를 통해 만약 오류가 생기면 원인을 알수 있게 함수 있음
try :
    html = urlopen('https://pythondojang.bitbucket.io/weather/observation/currentweather.html')
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    soup = BeautifulSoup(html.read(), 'html.parser')

# %%
import requests
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
import time

# %%
title = []


for i in range(1,11):
    url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=0&page='+str(i)+'&cnt=1000&SortOrder=1'
    req = requests.get(url)
    content = req.content
    
    soup = BeautifulSoup(content,'html.parser')
    book_name_elems = soup.select('a.bo3 b')
   

    for item in range(len(book_name_elems)):
        title.append(book_name_elems[item].get_text())

# %%
title
# Out:
# ['어떻게 말해줘야 할까',
#  '트렌드 코리아 2021',
#  '달러구트 꿈 백화점',
#  '마음챙김의 시',
#  '읽기만 하면 내 것이 되는 1페이지 미술 365',
#  '나의 하루는 4시 30분에 시작된다',
#  '설민석의 한국사 대모험 15',
#  '보건교사 안은영 (특별판)',
#  '추리소설가의 살인사건',
#  '고양이 해결사 깜냥 2',
#  '존리의 금융문맹 탈출',
#  '매우 예민한 사람들을 위한 책',
#  '흔한남매 6',
#  '습관의 디테일',
#  '쉬운 천국',
#  '하이큐!! 44',
#  '세계미래보고서 2021 (포스트 코로나 특별판)',
#  '부지런한 사랑',
#  '별뜨기에 관하여',
#  '그럼에도 불구하고',
#  '돈의 속성 (100쇄 기념 에디션, 양장)',
#  '이토록 공부가 재미있어지는 순간 (10만 부 기념 스페셜 에디션)',
#  '아이를 위한 돈의 감각',
#  '세계 미스터리 걸작선 1 : 살인자 외',
#  '초3보다 중요한 학년은 없습니다',
#  '명랑한 은둔자',
#  '에그박사 2',
#  '세계 미스터리 걸작선 2 : 모래시계 외',
#  'ETS 토익 정기시험 기출문제집 1000 Vol. 2 Reading (리딩)',
#  'ETS 토익 정기시험 기출문제집 1000 Vol. 2 Listening (리스닝)',
#  '부의 골든타임',
#  '손글씨 레시피',
#  '지박소년 하나코 군 13',
#  '오리진',
#  '공정하다는 착각',
#  '2021 인생일력',
#  '걸어 다니는 어원 사전',
#  '해커스 토익 기출 보카 TOEIC VOCA 단어장',
#  '거울명상',
#  '괜찮지 않을까, 우리가 함께라면',
#  '고양이를 버리다',
#  '해리 포터와 마법사의 돌 (미나리마 에디션)',
#  '연년세세',
#  '자유론',
#  '죽은 자의 집 청소',
#  '시선으로부터,',
#  '뇌는 팩트에 끌리지 않는다',
#  '비밀의 보석 가게 마석관 1',
# ...

# %%
file_format = ['(지은이)','(옮긴이)','(엮은이)','(글쓴이)','(작가)','(글)','(그림)','(편곡)']
book_list=[]
check=[]
path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

for b in range(1,11):
    url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=0&page='+str(b)+'&cnt=1000&SortOrder=1'
    driver.get(url)
    list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
    
    for a in range(50):
        split_ls =list[a].text.split('\n')
        check.append(split_ls)

# %%
for c in range(len(check)):
    for i in check[c]:
        if (file_format[0] in i) | (file_format[1] in i) | (file_format[2] in i)|(file_format[3] in i)|(file_format[4] in i)|(file_format[5] in i)|(file_format[6] in i)|(file_format[7] in i):      
            book_list.append(i)

# %%
len(book_list)
# Out:
# 500

# %%
book_list
# Out:
# ['오은영 (지은이), 차상미 (그림) | 김영사 | 2020년 10월',
#  '김난도, 전미영, 최지혜, 이향은, 이준영, 이수진, 서유현, 권정윤, 한다혜 (지은이) | 미래의창 | 2020년 10월',
#  '이미예 (지은이) | 팩토리나인 | 2020년 7월',
#  '류시화 (엮은이) | 수오서재 | 2020년 9월',
#  '김영숙 (지은이) | 비에이블 | 2020년 9월',
#  '김유진 (지은이) | 토네이도 | 2020년 10월',
#  '설민석, 스토리박스 (지은이), 정현희 (그림), 태건 역사 연구소 (감수) | 아이휴먼 | 2020년 10월',
#  '정세랑 (지은이) | 민음사 | 2020년 9월',
#  '히가시노 게이고 (지은이), 민경욱 (옮긴이) | ㈜소미미디어 | 2020년 10월',
#  '홍민정 (지은이), 김재희 (그림) | 창비 | 2020년 10월',
#  '존 리 (지은이) | 베가북스 | 2020년 10월',
#  '전홍진 (지은이) | 글항아리 | 2020년 7월',
#  '흔한남매 (지은이), 백난도 (글), 유난희 (그림), 흔한컴퍼니 (감수) | 아이세움 | 2020년 10월',
#  'BJ 포그 (지은이), 김미정 (옮긴이) | 흐름출판 | 2020년 10월',
#  '유지혜 (지은이) | 어떤책 | 2020년 11월',
#  '후루다테 하루이치 (지은이) | 대원씨아이(만화) | 2020년 11월',
#  '박영숙, 제롬 글렌 (지은이) | 비즈니스북스 | 2020년 10월',
#  '이슬아 (지은이) | 문학동네 | 2020년 10월',
#  '이영도 (지은이) | 황금가지 | 2020년 10월',
#  '공지영 (지은이) | 위즈덤하우스 | 2020년 10월',
#  '김승호 (지은이) | 스노우폭스북스 | 2020년 6월',
#  '박성혁 (지은이) | 다산북스 | 2020년 7월',
#  '베스 코블리너 (지은이), 이주만 (옮긴이) | 다산에듀 | 2020년 10월',
# ...

# %%
split_booklist=[]
author = []
publisher =[]

for s in range(len(book_list)):
    input = book_list[s].split('|')
    split_booklist.append(input)

    author.append(split_booklist[s][0])
    publisher.append(split_booklist[s][1])

# %%
split_booklist[0][0]
# Out:
# '오은영 (지은이), 차상미 (그림) '

# %%
print(split_booklist[0:5])
print(len(split_booklist))
print()
print(author[0:5])
print(len(author))
print()
print(publisher[0:5])
print(len(publisher))
# Out:
# [['오은영 (지은이), 차상미 (그림) ', ' 김영사 ', ' 2020년 10월'], ['김난도, 전미영, 최지혜, 이향은, 이준영, 이수진, 서유현, 권정윤, 한다혜 (지은이) ', ' 미래의창 ', ' 2020년 10월'], ['이미예 (지은이) ', ' 팩토리나인 ', ' 2020년 7월'], ['류시화 (엮은이) ', ' 수오서재 ', ' 2020년 9월'], ['김영숙 (지은이) ', ' 비에이블 ', ' 2020년 9월']]
# 500
#
# ['오은영 (지은이), 차상미 (그림) ', '김난도, 전미영, 최지혜, 이향은, 이준영, 이수진, 서유현, 권정윤, 한다혜 (지은이) ', '이미예 (지은이) ', '류시화 (엮은이) ', '김영숙 (지은이) ']
# 500
#
# [' 김영사 ', ' 미래의창 ', ' 팩토리나인 ', ' 수오서재 ', ' 비에이블 ']
# 500

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

no_df = pd.DataFrame({'title' : title,
                     'author' : author,
                     'publisher' : publisher})

# %%
no_df
# Out:
#                           title  \
# 0                   어떻게 말해줘야 할까
# 1                  트렌드 코리아 2021
# 2                    달러구트 꿈 백화점
# 3                       마음챙김의 시
# 4    읽기만 하면 내 것이 되는 1페이지 미술 365
# ..                          ...
# 495                   주식회사 랩추종윤
# 496                    인형의 나라 6
# 497                      변화하는 뇌
# 498             2021 해리포터 탁상 달력
# 499               지박소년 하나코 군 12
#
#                                                 author publisher
# 0                                 오은영 (지은이), 차상미 (그림)       김영사
# 1    김난도, 전미영, 최지혜, 이향은, 이준영, 이수진, 서유현, 권정윤, 한다혜 (지...     미래의창
# 2                                           이미예 (지은이)     팩토리나인
# 3                                           류시화 (엮은이)      수오서재
# 4                                           김영숙 (지은이)      비에이블
# ..                                                 ...       ...
# 495                                    이주헌, 박종윤 (지은이)    브레인스토어
# ...

# %% [markdown]
# - 청소년 도서 크롤링

# %%
# 크롤링 간단 코드 

from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
# url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=0&page=2&cnt=1000&SortOrder=1'
# driver.get(url)

# list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
# split_ls = list[0].text.split('\n')

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)']
book_list2 = []

# %%
# 청소년 도서 1~10 월

for month in range(1,11):
    
    for page in range(1,11):
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=1137&Year=2020&Month='+str(month)+'&Week=2&page='+str(page)+'&cnt=1000&SortOrder=1'

        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")

        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j):
                    book_list2.append(j)
                    break

# %%
len(book_list2)
# Out:
# 5000

# %%
split_booklist2=[]
author2 = []
publisher2 =[]

for s in range(len(book_list2)):
    input = book_list2[s].split('|')
    split_booklist2.append(input)

    author2.append(split_booklist2[s][0])
    publisher2.append(split_booklist2[s][1])

# %%
print(split_booklist2[0:5])
print(len(split_booklist2))
print()
print(author2[0:5])
print(len(author2))
print()
print(publisher2[0:5])
print(len(publisher2))
# Out:
# [['이윤규 (지은이) ', ' 비즈니스북스 ', ' 2019년 12월'], ['칼 세이건 (지은이), 홍승수 (옮긴이) ', ' 사이언스북스 ', ' 2006년 12월'], ['손원평 (지은이) ', ' 창비 ', ' 2017년 3월'], ['칼 세이건 (지은이), 홍승수 (옮긴이) ', ' 사이언스북스 ', ' 2004년 12월'], ['조승우 (지은이) ', ' 포레스트북스 ', ' 2019년 12월']]
# 5000
#
# ['이윤규 (지은이) ', '칼 세이건 (지은이), 홍승수 (옮긴이) ', '손원평 (지은이) ', '칼 세이건 (지은이), 홍승수 (옮긴이) ', '조승우 (지은이) ']
# 5000
#
# [' 비즈니스북스 ', ' 사이언스북스 ', ' 창비 ', ' 사이언스북스 ', ' 포레스트북스 ']
# 5000

# %%
# 책 제목 

title2 = []

for month in range(1,11):

    for i in range(1,11):
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=1137&Year=2020&Month='+str(month)+'&Week=2&page='+str(page)+'&cnt=1000&SortOrder=1'

        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')


        for item in range(len(book_name_elems)):
            title2.append(book_name_elems[item].get_text())

# %%
len(title2)
# Out:
# 5000

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

teenager = pd.DataFrame({'title' : title2,
                     'author' : author2,
                     'publisher' : publisher2})

# %%
teenager.head()
# Out:
#                    title                   author publisher
# 0                  윤미네 집               이윤규 (지은이)    비즈니스북스
# 1           사람은 무엇으로 사는가  칼 세이건 (지은이), 홍승수 (옮긴이)    사이언스북스
# 2                   삼국사기               손원평 (지은이)        창비
# 3  원숭이는 왜 철학 교사가 될 수 없을까  칼 세이건 (지은이), 홍승수 (옮긴이)    사이언스북스
# 4               아틀라스 세계사               조승우 (지은이)    포레스트북스

# %%
# 중복데이터 제거
cc = teenager.drop_duplicates('title',keep='first')
len(cc)
# Out:
# 416

# %%
# csv 저장
cc.to_csv('C:\\Users\\kim23\\data\\final\\teenager.csv',index=False,encoding='euc-kr')

# %% [markdown]
# - 어린이 도서

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)','(원작)','(참고서)','(캐릭터)','(기획)','(구성)','(디자인)','(해설)']
book_list3 = []

# %%
# 어린이 도서 1~10 월

for month in range(1,11):
    
    for page in range(1,11):
        
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=1108&Year=2020&Month='+str(month)+'&Week=2&page='+str(page)+'&cnt=1000&SortOrder=1'

        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")

        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j)| (file_format[7] in j) | (file_format[8] in j)|(file_format[9] in j)|(file_format[10] in j)|(file_format[11] in j)|(file_format[12] in j)|(file_format[13] in j):
                    book_list3.append(j)
                    break

# %%
len(book_list3)
# Out:
# 5000

# %%
# 작가, 출판사 가져오기

split_booklist3=[]
author3 = []
publisher3 =[]

for s in range(len(book_list3)):
    input = book_list3[s].split('|')
    split_booklist3.append(input)

    author3.append(split_booklist3[s][0])
    publisher3.append(split_booklist3[s][1])

# %%
# 확인
print(split_booklist3[0:5])
print(len(split_booklist3))
print()
print(author3[0:5])
print(len(author3))
print()
print(publisher3[0:5])
print(len(publisher3))
# Out:
# [['흔한남매 (지은이), 백난도 (글), 유난희 (그림), 샌드박스 네트워크 (감수) ', ' 아이세움 ', ' 2020년 1월'], ['트롤 (지은이), 김정화 (옮긴이) ', ' 아이세움 ', ' 2020년 1월'], ['앤디 그리피스 (지은이), 테리 덴톤 (그림), 신수진 (옮긴이) ', ' 시공주니어 ', ' 2020년 1월'], ['설민석, 잼 스토리 (지은이), 박성일 (그림) ', ' 단꿈아이 ', ' 2020년 1월'], ['김현수 (지은이), 홍거북 (그림), 김창환 (감수) ', ' 아울북 ', ' 2020년 1월']]
# 5000
#
# ['흔한남매 (지은이), 백난도 (글), 유난희 (그림), 샌드박스 네트워크 (감수) ', '트롤 (지은이), 김정화 (옮긴이) ', '앤디 그리피스 (지은이), 테리 덴톤 (그림), 신수진 (옮긴이) ', '설민석, 잼 스토리 (지은이), 박성일 (그림) ', '김현수 (지은이), 홍거북 (그림), 김창환 (감수) ']
# 5000
#
# [' 아이세움 ', ' 아이세움 ', ' 시공주니어 ', ' 단꿈아이 ', ' 아울북 ']
# 5000

# %%
# 책 제목 

title3 = []

for month in range(1,11):

    for page in range(1,11):
        
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=1108&Year=2020&Month='+str(month)+'&Week=2&page='+str(page)+'&cnt=1000&SortOrder=1'

    
        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')


        for item in range(len(book_name_elems)):
            title3.append(book_name_elems[item].get_text())

# %%
len(title3)
# Out:
# 5000

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

kid = pd.DataFrame({'title' : title3,
                     'author' : author3,
                     'publisher' : publisher3})

# %%
kid.head()
# Out:
#             title                                          author publisher
# 0          흔한남매 3  흔한남매 (지은이), 백난도 (글), 유난희 (그림), 샌드박스 네트워크 (감수)      아이세움
# 1  추리 천재 엉덩이 탐정 9                            트롤 (지은이), 김정화 (옮긴이)      아이세움
# 2       117층 나무 집           앤디 그리피스 (지은이), 테리 덴톤 (그림), 신수진 (옮긴이)     시공주니어
# 3  설민석의 세계사 대모험 4                     설민석, 잼 스토리 (지은이), 박성일 (그림)      단꿈아이
# 4        마법천자문 47                  김현수 (지은이), 홍거북 (그림), 김창환 (감수)       아울북

# %%
# csv 저장
kid.to_csv('C:\\Users\\kim23\\data\\final\\kid.csv',index=False,encoding='euc-kr')

# %%
# 중복데이터 제거
kid_remove = kid.drop_duplicates('title',keep='first')
len(kid_remove)
# Out:
# 1469

# %%
# csv 저장 - 수정후 
kid_remove.to_csv('C:\\Users\\kim23\\data\\final\\kid_remove.csv',index=False,encoding='euc-kr')

# %% [markdown]
# - 종합 책 크롤링 1~10

# %%
from tqdm import tqdm_notebook

from tqdm import tqdm
from tqdm import trange

# %%
list[0].find_element_by_tag_name('img').get_attribute('src')
# Out:
# 'https://image.aladin.co.kr/product/22327/46/cover150/k782636924_1.jpg'

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)','(원작)','(참고서)','(캐릭터)','(기획)','(구성)','(디자인)','(해설)','김은숙, 김수연']
book_list4 = []
image4 =[]
title4 = []

# %%
# 종합 도서 1~10 월



for month in tqdm_notebook(range(1,11)):

    for page in range(1,11):

        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=0&Year=2020&Month='+str(month)+'&Week=2&page='+str(page)+'&cnt=1000&SortOrder=1'

        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
        
        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')


        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')
            image_ls = list[i].find_element_by_tag_name('img').get_attribute('src')
            image4.append(image_ls)
            title4.append(book_name_elems[i].get_text())

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j)| (file_format[7] in j) | (file_format[8] in j)|(file_format[9] in j)|(file_format[10] in j)|(file_format[11] in j)|(file_format[12] in j)|(file_format[13] in j)|(file_format[14] in j):
                    book_list4.append(j)
                    break
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# ...

# %%
print(len(title4))
print(len(image4))
# Out:
# 5000
# 5000

# %%
# 작가, 출판사 가져오기

split_booklist4=[]
author4 = []
publisher4 =[]

for s in range(len(book_list4)):
    input = book_list4[s].split('|')
    split_booklist4.append(input)

    author4.append(split_booklist4[s][0])
    publisher4.append(split_booklist4[s][1])

# %%
# 확인
print(split_booklist4[0:5])
print(len(split_booklist4))
print()
print(author4[0:5])
print(len(author4))
print()
print(publisher4[0:5])
print(len(publisher4))
# Out:
# [['흔한남매 (지은이), 백난도 (글), 유난희 (그림), 샌드박스 네트워크 (감수) ', ' 아이세움 ', ' 2020년 1월'], ['채사장 (지은이) ', ' 웨일북 ', ' 2019년 12월'], ['묵향동후 (지은이), 이현아 (옮긴이) ', ' B-Lab ', ' 2020년 1월'], ['트롤 (지은이), 김정화 (옮긴이) ', ' 아이세움 ', ' 2020년 1월'], ['이지성 (지은이) ', ' 차이정원 ', ' 2019년 10월']]
# 5000
#
# ['흔한남매 (지은이), 백난도 (글), 유난희 (그림), 샌드박스 네트워크 (감수) ', '채사장 (지은이) ', '묵향동후 (지은이), 이현아 (옮긴이) ', '트롤 (지은이), 김정화 (옮긴이) ', '이지성 (지은이) ']
# 5000
#
# [' 아이세움 ', ' 웨일북 ', ' B-Lab ', ' 아이세움 ', ' 차이정원 ']
# 5000

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

book = pd.DataFrame({'title' : title4,
                     'author' : author4,
                     'publisher' : publisher4,
                    'image' : image4})

# %%
# csv 저장
book.to_csv('C:\\Users\\kim23\\data\\final\\book.csv',index=False,encoding ='utf-8-sig')

# %%
# 중복데이터 제거
book_remove = book.drop_duplicates('title',keep='first')
len(book_remove)
# Out:
# 2315

# %%
# csv 저장 - 수정후 
book_remove.to_csv('C:\\Users\\kim23\\data\\final\\book_remove.csv',index=False,encoding='utf-8-sig')

# %% [markdown]
# ### 청소년 도서

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)','(원작)','(참고서)','(캐릭터)','(기획)','(구성)','(디자인)','(해설)']
book_list1 = []
image1 =[]
title1 = []

# %%
# 종합 도서 1~10 월



for month in tqdm_notebook(range(1,11)):

    for page in range(1,11):
        
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=1137&Year=2020&Month='+str(month)+'&Week=2&page='+str(page)+'&cnt=1000&SortOrder=1'

        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
        
        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')


        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')
            image_ls = list[i].find_element_by_tag_name('img').get_attribute('src')
            image1.append(image_ls)
            title1.append(book_name_elems[i].get_text())

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j)| (file_format[7] in j) | (file_format[8] in j)|(file_format[9] in j)|(file_format[10] in j)|(file_format[11] in j)|(file_format[12] in j)|(file_format[13] in j):
                    book_list1.append(j)
                    break
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# ...

# %%
print(len(title1))
print(len(image1))
# Out:
# 5000
# 5000

# %%
# 작가, 출판사 가져오기

split_booklist1=[]
author1 = []
publisher1 =[]

for s in range(len(book_list1)):
    input = book_list1[s].split('|')
    split_booklist1.append(input)

    author1.append(split_booklist1[s][0])
    publisher1.append(split_booklist1[s][1])

# %%
# 확인
print(split_booklist1[0:5])
print(len(split_booklist1))
print()
print(author1[0:5])
print(len(author1))
print()
print(publisher1[0:5])
print(len(publisher1))
# Out:
# [['이윤규 (지은이) ', ' 비즈니스북스 ', ' 2019년 12월'], ['칼 세이건 (지은이), 홍승수 (옮긴이) ', ' 사이언스북스 ', ' 2006년 12월'], ['손원평 (지은이) ', ' 창비 ', ' 2017년 3월'], ['칼 세이건 (지은이), 홍승수 (옮긴이) ', ' 사이언스북스 ', ' 2004년 12월'], ['조승우 (지은이) ', ' 포레스트북스 ', ' 2019년 12월']]
# 5000
#
# ['이윤규 (지은이) ', '칼 세이건 (지은이), 홍승수 (옮긴이) ', '손원평 (지은이) ', '칼 세이건 (지은이), 홍승수 (옮긴이) ', '조승우 (지은이) ']
# 5000
#
# [' 비즈니스북스 ', ' 사이언스북스 ', ' 창비 ', ' 사이언스북스 ', ' 포레스트북스 ']
# 5000

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

teenager = pd.DataFrame({'title' : title1,
                     'author' : author1,
                     'publisher' : publisher1,
                    'image' : image1})

# %%
teenager.tail()
# Out:
#                            title           author  publisher  \
# 4995                한국사에서 수학을 보다       이광연 (지은이)     위즈덤하우스
# 4996                   442 시간 법칙       하태호 (지은이)    중앙경제평론사
# 4997           청소년을 위한 고전 소설 에세이       류수열 (지은이)         해냄
# 4998                국어시간에 소설읽기 2  전국국어교사모임 (엮은이)      휴머니스트
# 4999  국어 교과서 작품 읽기 중3 소설 (전면개정판)  서덕희, 최은영 (엮은이)         창비
#
#                                                   image
# 4995  https://image.aladin.co.kr/product/24265/5/cov...
# 4996  https://image.aladin.co.kr/product/24244/67/co...
# 4997  https://image.aladin.co.kr/product/23828/64/co...
# 4998  https://image.aladin.co.kr/product/23533/16/co...
# 4999  https://image.aladin.co.kr/product/21984/29/co...

# %%
# csv 저장
teenager.to_csv('C:\\Users\\kim23\\data\\final\\teenager.csv',index=False,encoding ='utf-8-sig')

# %%
# 중복데이터 제거
teenager_remove = teenager.drop_duplicates('title',keep='first')
len(teenager_remove)
# Out:
# 1494

# %%
# csv 저장
teenager_remove.to_csv('C:\\Users\\kim23\\data\\final\\teenager_remove.csv',index=False,encoding ='utf-8-sig')

# %% [markdown]
# ### 장르소설

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)','(원작)','(참고서)','(캐릭터)','(기획)','(구성)','(디자인)','(해설)']
book_list3 = []
image3 =[]
title3 = []

# %%
# 종합 도서 1~10 월
cnt = 0

for month in tqdm_notebook(range(1,11)):

    for page in range(1,6):
        
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=112011&Year=2020&Month='+str(month)+'&Week=3&page='+str(page)+'&cnt=1000&SortOrder=1'
        
        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
        
        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')


        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')
            image_ls = list[i].find_element_by_tag_name('img').get_attribute('src')
            image3.append(image_ls)
            title3.append(book_name_elems[i].get_text())

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j)| (file_format[7] in j) | (file_format[8] in j)|(file_format[9] in j)|(file_format[10] in j)|(file_format[11] in j)|(file_format[12] in j)|(file_format[13] in j):
                    book_list3.append(j)
                    cnt +=1
                    break
                    
        print('{}월 {}페이지 cnt = {}'.format(month, page, cnt))
        cnt = 0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# ...

# %%
print(len(title3))
print(len(image3))
# Out:
# 2500
# 2500

# %%
# 작가, 출판사 가져오기

split_booklist3=[]
author3 = []
publisher3 =[]

for s in range(len(book_list3)):
    input = book_list3[s].split('|')
    split_booklist3.append(input)

    author3.append(split_booklist3[s][0])
    publisher3.append(split_booklist3[s][1])

# %%
# 확인
print(split_booklist3[0:5])
print(len(split_booklist3))
print()
print(author3[0:5])
print(len(author3))
print()
print(publisher3[0:5])
print(len(publisher3))
# Out:
# [['묵향동후 (지은이), 이현아 (옮긴이) ', ' B-Lab ', ' 2020년 1월'], ['김초엽 (지은이) ', ' 허블 ', ' 2019년 6월'], ['묵향동후 (지은이), 이현아 (옮긴이) ', ' B-Lab ', ' 2020년 1월'], ['묵향동후 (지은이), 이현아 (옮긴이) ', ' B-Lab ', ' 2019년 7월'], ['묵향동후 (지은이), 이현아 (옮긴이) ', ' B-Lab ', ' 2019년 11월']]
# 2500
#
# ['묵향동후 (지은이), 이현아 (옮긴이) ', '김초엽 (지은이) ', '묵향동후 (지은이), 이현아 (옮긴이) ', '묵향동후 (지은이), 이현아 (옮긴이) ', '묵향동후 (지은이), 이현아 (옮긴이) ']
# 2500
#
# [' B-Lab ', ' 허블 ', ' B-Lab ', ' B-Lab ', ' B-Lab ']
# 2500

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

genre_fiction = pd.DataFrame({'title' : title3,
                     'author' : author3,
                     'publisher' : publisher3,
                    'image' : image3})

# %%
genre_fiction.tail()
# Out:
#                             title                         author  \
# 2495             신데렐라를 곱게 키웠습니다 1                    키아르네 (지은이)
# 2496             바람의 그림자 (합본 특별판)  카를로스 루이스 사폰 (지은이), 정동섭 (옮긴이)
# 2497                      타오르는 마음                     이두온 (지은이)
# 2498  거짓말이 보이는 나는, 솔직한 너에게 사랑을 했다      사쿠라이 미나 (지은이), 주승현 (옮긴이)
# 2499           벚꽃지는 계절에 그대를 그리워하네       우타노 쇼고 (지은이), 김성기 (옮긴이)
#
#            publisher                                              image
# 2495            피오렛   https://image.aladin.co.kr/product/25115/6/cov...
# 2496           문학동네   https://image.aladin.co.kr/product/24992/36/co...
# 2497           은행나무   https://image.aladin.co.kr/product/24410/48/co...
# 2498          제우미디어   https://image.aladin.co.kr/product/20447/34/co...
# 2499   한즈미디어(한스미디어)   https://image.aladin.co.kr/product/18731/44/co...

# %%
# csv 저장
genre_fiction.to_csv('C:\\Users\\kim23\\data\\final\\genre_fiction.csv',index=False,encoding ='utf-8-sig')

# %%
# 중복데이터 제거
genre_fiction_remove = genre_fiction.drop_duplicates('title',keep='first')
len(genre_fiction_remove)
# Out:
# 989

# %%
# csv 저장
genre_fiction_remove.to_csv('C:\\Users\\kim23\\data\\final\\genre_fiction_remove.csv',index=False,encoding ='utf-8-sig')

# %% [markdown]
# ### 자기계발

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)','(원작)','(참고서)','(캐릭터)','(기획)','(구성)','(디자인)','(해설)']
book_list4 = []
image4 =[]
title4 = []

# %%
# 종합 도서 1~10 월


for month in tqdm_notebook(range(1,11)):

    for page in range(1,6):
        
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=336&Year=2020&Month='+str(month)+'&Week=3&page='+str(page)+'&cnt=1000&SortOrder=1'
        
        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
        
        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')


        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')
            image_ls = list[i].find_element_by_tag_name('img').get_attribute('src')
            image4.append(image_ls)
            title4.append(book_name_elems[i].get_text())

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j)| (file_format[7] in j) | (file_format[8] in j)|(file_format[9] in j)|(file_format[10] in j)|(file_format[11] in j)|(file_format[12] in j)|(file_format[13] in j):
                    book_list4.append(j)
                    break
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# ...

# %%
print(len(title4))
print(len(image4))
# Out:
# 2500
# 2500

# %%
# 작가, 출판사 가져오기

split_booklist4=[]
author4 = []
publisher4 =[]

for s in range(len(book_list4)):
    input = book_list4[s].split('|')
    split_booklist4.append(input)

    author4.append(split_booklist4[s][0])
    publisher4.append(split_booklist4[s][1])

# %%
# 확인
print(split_booklist4[0:5])
print(len(split_booklist4))
print()
print(author4[0:5])
print(len(author4))
print()
print(publisher4[0:5])
print(len(publisher4))
# Out:
# [['이지성 (지은이) ', ' 차이정원 ', ' 2019년 10월'], ['이윤규 (지은이) ', ' 비즈니스북스 ', ' 2019년 12월'], ['웬디 우드 (지은이), 김윤재 (옮긴이) ', ' 다산북스 ', ' 2019년 12월'], ['제임스 클리어 (지은이), 이한이 (옮긴이) ', ' 비즈니스북스 ', ' 2019년 2월'], ['제임스 도티 (지은이), 주민아 (옮긴이) ', ' 판미동 ', ' 2019년 12월']]
# 2500
#
# ['이지성 (지은이) ', '이윤규 (지은이) ', '웬디 우드 (지은이), 김윤재 (옮긴이) ', '제임스 클리어 (지은이), 이한이 (옮긴이) ', '제임스 도티 (지은이), 주민아 (옮긴이) ']
# 2500
#
# [' 차이정원 ', ' 비즈니스북스 ', ' 다산북스 ', ' 비즈니스북스 ', ' 판미동 ']
# 2500

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

self_improvement = pd.DataFrame({'title' : title4,
                     'author' : author4,
                     'publisher' : publisher4,
                    'image' : image4})

# %%
self_improvement.tail()
# Out:
#                 title                       author   publisher  \
# 2495         개구리를 먹어라  브라이언 트레이시 (지은이), 이옥용 (옮긴이)        북앳북스
# 2496        우주 리듬을 타라     디팩 초프라 (지은이), 이현주 (옮긴이)          샨티
# 2497         마스터리의 법칙     로버트 그린 (지은이), 이수경 (옮긴이)          살림
# 2498       뇌를 움직이는 메모     사카토 켄지 (지은이), 김하경 (옮긴이)      비즈니스세상
# 2499  네 안에 잠든 거인을 깨워라    앤서니 라빈스 (지은이), 조진형 (옮긴이)    씨앗을뿌리는사람
#
#                                                   image
# 2495  https://image.aladin.co.kr/product/3278/16/cov...
# 2496  https://image.aladin.co.kr/product/2908/50/cov...
# 2497  https://image.aladin.co.kr/product/2790/40/cov...
# 2498  https://image.aladin.co.kr/product/436/97/cove...
# 2499  https://image.aladin.co.kr/product/193/28/cove...

# %%
# csv 저장
self_improvement.to_csv('C:\\Users\\kim23\\data\\final\\self_improvement.csv',index=False,encoding ='utf-8-sig')

# %%
# 중복데이터 제거
self_improvement_remove = self_improvement.drop_duplicates('title',keep='first')
len(self_improvement_remove)
# Out:
# 758

# %%
# csv 저장
self_improvement_remove.to_csv('C:\\Users\\kim23\\data\\final\\self_improvement_remove.csv',index=False,encoding ='utf-8-sig')

# %% [markdown]
# ### 인문학

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)','(원작)','(참고서)','(캐릭터)','(기획)','(구성)','(디자인)','(해설)']
book_list5 = []
image5 =[]
title5 = []

# %%
# 종합 도서 1~10 월


for month in tqdm_notebook(range(1,11)):

    for page in range(1,6):
    
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=656&Year=2020&Month='+str(month)+'&Week=3&page='+str(page)+'&cnt=1000&SortOrder=1'
        
        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
        
        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')


        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')
            image_ls = list[i].find_element_by_tag_name('img').get_attribute('src')
            image5.append(image_ls)
            title5.append(book_name_elems[i].get_text())

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j)| (file_format[7] in j) | (file_format[8] in j)|(file_format[9] in j)|(file_format[10] in j)|(file_format[11] in j)|(file_format[12] in j)|(file_format[13] in j):
                    book_list5.append(j)
                    break
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# ...

# %%
print(len(title5))
print(len(image5))
# Out:
# 2500
# 2500

# %%
# 작가, 출판사 가져오기

split_booklist5=[]
author5 = []
publisher5 =[]

for s in range(len(book_list5)):
    input = book_list5[s].split('|')
    split_booklist5.append(input)

    author5.append(split_booklist5[s][0])
    publisher5.append(split_booklist5[s][1])

# %%
# 확인
print(split_booklist5[0:5])
print(len(split_booklist5))
print()
print(author5[0:5])
print(len(author5))
print()
print(publisher5[0:5])
print(len(publisher5))
# Out:
# [['채사장 (지은이) ', ' 웨일북 ', ' 2019년 12월'], ['데이비드 S. 키더, 노아 D. 오펜하임 (지은이), 허성심 (옮긴이) ', ' 위즈덤하우스 ', ' 2019년 10월'], ['올리버 색스 (지은이), 이정호 (그림), 조석현 (옮긴이) ', ' 알마 ', ' 2016년 8월'], ['한스 로슬링, 올라 로슬링, 안나 로슬링 뢴룬드 (지은이), 이창신 (옮긴이) ', ' 김영사 ', ' 2019년 3월'], ['유발 하라리 (지은이), 조현욱 (옮긴이), 이태수 (감수) ', ' 김영사 ', ' 2015년 11월']]
# 2500
#
# ['채사장 (지은이) ', '데이비드 S. 키더, 노아 D. 오펜하임 (지은이), 허성심 (옮긴이) ', '올리버 색스 (지은이), 이정호 (그림), 조석현 (옮긴이) ', '한스 로슬링, 올라 로슬링, 안나 로슬링 뢴룬드 (지은이), 이창신 (옮긴이) ', '유발 하라리 (지은이), 조현욱 (옮긴이), 이태수 (감수) ']
# 2500
#
# [' 웨일북 ', ' 위즈덤하우스 ', ' 알마 ', ' 김영사 ', ' 김영사 ']
# 2500

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

humanities = pd.DataFrame({'title' : title5,
                     'author' : author5,
                     'publisher' : publisher5,
                    'image' : image5})

# %%
humanities.tail()
# Out:
#                      title                           author     publisher  \
# 2495  정적 : 나를 변화시키는 조용한 기적                       배철현 (지은이)        21세기북스
# 2496                  다크호스  토드 로즈, 오기 오가스 (지은이), 정미나 (옮긴이)        21세기북스
# 2497                 놓아 버림       데이비드 호킨스 (지은이), 박찬준 (옮긴이)           판미동
# 2498                예술의 쓸모                       강은진 (지은이)    다산초당(다산북스)
# 2499                   크리톤            플라톤 (지은이), 이기백 (옮긴이)           아카넷
#
#                                                   image
# 2495  https://image.aladin.co.kr/product/20775/34/co...
# 2496  https://image.aladin.co.kr/product/20166/4/cov...
# 2497  https://image.aladin.co.kr/product/3226/29/cov...
# 2498  https://image.aladin.co.kr/product/25093/39/co...
# 2499  https://image.aladin.co.kr/product/24794/80/co...

# %%
# csv 저장
humanities.to_csv('C:\\Users\\kim23\\data\\final\\humanities.csv',index=False,encoding ='utf-8-sig')

# %%
# 중복데이터 제거
humanities_remove = humanities.drop_duplicates('title',keep='first')
len(humanities_remove)
# Out:
# 925

# %%
# csv 저장
humanities_remove.to_csv('C:\\Users\\kim23\\data\\final\\humanities_remove.csv',index=False,encoding ='utf-8-sig')

# %% [markdown]
# ### 과학

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)','(원작)','(참고서)','(캐릭터)','(기획)','(구성)','(디자인)','(해설)']
book_list6 = []
image6 =[]
title6 = []

# %%
# 종합 도서 1~10 월


for month in tqdm_notebook(range(1,11)):

    for page in range(1,6):
        
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=987&Year=2020&Month='+str(month)+'&Week=3&page='+str(page)+'&cnt=1000&SortOrder=1'
        
        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
        
        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')


        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')
            image_ls = list[i].find_element_by_tag_name('img').get_attribute('src')
            image6.append(image_ls)
            title6.append(book_name_elems[i].get_text())

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j)| (file_format[7] in j) | (file_format[8] in j)|(file_format[9] in j)|(file_format[10] in j)|(file_format[11] in j)|(file_format[12] in j)|(file_format[13] in j):
                    book_list6.append(j)
                    break
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# ...

# %%
print(len(title6))
print(len(image6))
# Out:
# 2500
# 2500

# %%
# 작가, 출판사 가져오기

split_booklist6=[]
author6 = []
publisher6 =[]

for s in range(len(book_list6)):
    input = book_list6[s].split('|')
    split_booklist6.append(input)

    author6.append(split_booklist6[s][0])
    publisher6.append(split_booklist6[s][1])

# %%
# 확인
print(split_booklist6[0:5])
print(len(split_booklist6))
print()
print(author6[0:5])
print(len(author6))
print()
print(publisher6[0:5])
print(len(publisher6))
# Out:
# [['칼 세이건 (지은이), 홍승수 (옮긴이) ', ' 사이언스북스 ', ' 2006년 12월'], ['올리버 색스 (지은이), 이정호 (그림), 조석현 (옮긴이) ', ' 알마 ', ' 2016년 8월'], ['빌 브라이슨 (지은이), 이한음 (옮긴이) ', ' 까치 ', ' 2020년 1월'], ['리처드 도킨스 (지은이), 홍영남, 이상임 (옮긴이) ', ' 을유문화사 ', ' 2018년 10월'], ['김범준 (지은이) ', ' 동아시아 ', ' 2019년 12월']]
# 2500
#
# ['칼 세이건 (지은이), 홍승수 (옮긴이) ', '올리버 색스 (지은이), 이정호 (그림), 조석현 (옮긴이) ', '빌 브라이슨 (지은이), 이한음 (옮긴이) ', '리처드 도킨스 (지은이), 홍영남, 이상임 (옮긴이) ', '김범준 (지은이) ']
# 2500
#
# [' 사이언스북스 ', ' 알마 ', ' 까치 ', ' 을유문화사 ', ' 동아시아 ']
# 2500

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

science = pd.DataFrame({'title' : title6,
                     'author' : author6,
                     'publisher' : publisher6,
                    'image' : image6})

# %%
science.tail()
# Out:
#                  title                                  author  \
# 2495  할리데이 일반물리학 문제풀이집  J. Richard Christman (지은이), 김인묵 (옮긴이)
# 2496            통찰의 시대                 에릭 캔델 (지은이), 이한음 (옮긴이)
# 2497      미술관에 간 화학자 1                              전창림 (지은이)
# 2498             진화심리학     데이비드 버스 (지은이), 이충호 (옮긴이), 최재천 (감수)
# 2499             의식 혁명              데이비드 호킨스 (지은이), 백영미 (옮긴이)
#
#            publisher                                              image
# 2495           범한서적   https://image.aladin.co.kr/product/5945/81/cov...
# 2496   알에이치코리아(RHK)   https://image.aladin.co.kr/product/4702/58/cov...
# 2497          어바웃어북   https://image.aladin.co.kr/product/2390/50/cov...
# 2498        웅진지식하우스   https://image.aladin.co.kr/product/1766/98/cov...
# 2499            판미동   https://image.aladin.co.kr/product/1306/53/cov...

# %%
# csv 저장
science.to_csv('C:\\Users\\kim23\\data\\final\\science.csv',index=False,encoding ='utf-8-sig')

# %%
# 중복데이터 제거
science_remove = science.drop_duplicates('title',keep='first')
len(humanities_remove)
# Out:
# 925

# %%
# csv 저장
science_remove.to_csv('C:\\Users\\kim23\\data\\final\\science_remove.csv',index=False,encoding ='utf-8-sig')

# %% [markdown]
# ### 경제경영

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)','(원작)','(참고서)','(캐릭터)','(기획)','(구성)','(디자인)','(해설)']
book_list7 = []
image7 =[]
title7 = []

# %%
# 종합 도서 1~10 월
cnt = 0

for month in tqdm_notebook(range(1,11)):

    for page in range(1,6):
        
        url ='https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=170&Year=2020&Month='+str(month)+'&Week=3&page='+str(page)+'+&cnt=1000&SortOrder=1'
        
        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
        
        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')

        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')
            image_ls = list[i].find_element_by_tag_name('img').get_attribute('src')
            image7.append(image_ls)
            title7.append(book_name_elems[i].get_text())

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j)| (file_format[7] in j) | (file_format[8] in j)|(file_format[9] in j)|(file_format[10] in j)|(file_format[11] in j)|(file_format[12] in j)|(file_format[13] in j):
                    book_list7.append(j)
                    cnt +=1
                    break
                    
        print('{}월 {}페이지 cnt = {}'.format(month, page, cnt))
        cnt = 0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# ...
# 1월 1페이지 cnt = 50
# 1월 2페이지 cnt = 50
# 1월 3페이지 cnt = 50
# 1월 4페이지 cnt = 50
# 1월 5페이지 cnt = 50
# 2월 1페이지 cnt = 50
# 2월 2페이지 cnt = 50
# 2월 3페이지 cnt = 50
# 2월 4페이지 cnt = 50
# 2월 5페이지 cnt = 50
# 3월 1페이지 cnt = 50
# 3월 2페이지 cnt = 50
# 3월 3페이지 cnt = 50
# 3월 4페이지 cnt = 50
# 3월 5페이지 cnt = 50
# 4월 1페이지 cnt = 50
# 4월 2페이지 cnt = 50
# 4월 3페이지 cnt = 50
# 4월 4페이지 cnt = 50
# 4월 5페이지 cnt = 50
# 5월 1페이지 cnt = 50
# 5월 2페이지 cnt = 50
# 5월 3페이지 cnt = 50
# 5월 4페이지 cnt = 50
# 5월 5페이지 cnt = 50
# 6월 1페이지 cnt = 50
# 6월 2페이지 cnt = 50
# 6월 3페이지 cnt = 50
# 6월 4페이지 cnt = 50
# 6월 5페이지 cnt = 50
# 7월 1페이지 cnt = 50
# 7월 2페이지 cnt = 50
# 7월 3페이지 cnt = 50
# 7월 4페이지 cnt = 50
# 7월 5페이지 cnt = 50
# 8월 1페이지 cnt = 50
# 8월 2페이지 cnt = 50
# 8월 3페이지 cnt = 50
# 8월 4페이지 cnt = 50
# ...

# %%
print(len(title7))
print(len(image7))
# Out:
# 2500
# 2500

# %%
# 작가, 출판사 가져오기

split_booklist7=[]
author7 = []
publisher7 =[]

for s in range(len(book_list7)):
    input = book_list7[s].split('|')
    split_booklist7.append(input)

    author7.append(split_booklist7[s][0])
    publisher7.append(split_booklist7[s][1])

# %%
# 확인
print(split_booklist7[0:5])
print(len(split_booklist7))
print()
print(author7[0:5])
print(len(author7))
print()
print(publisher7[0:5])
print(len(publisher7))
# Out:
# [['김난도, 전미영, 최지혜, 이향은, 이준영, 김서영, 이수진, 서유현, 권정윤 (지은이) ', ' 미래의창 ', ' 2019년 10월'], ['세스 고딘 (지은이), 윤영삼 (옮긴이) ', ' 라이스메이커 ', ' 2019년 12월'], ['라밋 세티 (지은이), 김태훈 (옮긴이) ', ' 안드로메디안 ', ' 2019년 12월'], ['엠제이 드마코 (지은이), 신소영 (옮긴이) ', ' 토트 ', ' 2013년 8월'], ['브레네 브라운 (지은이), 강주헌 (옮긴이) ', ' 갤리온 ', ' 2019년 12월']]
# 2500
#
# ['김난도, 전미영, 최지혜, 이향은, 이준영, 김서영, 이수진, 서유현, 권정윤 (지은이) ', '세스 고딘 (지은이), 윤영삼 (옮긴이) ', '라밋 세티 (지은이), 김태훈 (옮긴이) ', '엠제이 드마코 (지은이), 신소영 (옮긴이) ', '브레네 브라운 (지은이), 강주헌 (옮긴이) ']
# 2500
#
# [' 미래의창 ', ' 라이스메이커 ', ' 안드로메디안 ', ' 토트 ', ' 갤리온 ']
# 2500

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

business = pd.DataFrame({'title' : title7,
                     'author' : author7,
                     'publisher' : publisher7,
                    'image' : image7})

# %%
business.tail()
# Out:
#                          title                          author publisher  \
# 2495  혼자 일하며 연봉 10억 버는 사람들의 비밀                      최창희 (지은이)     책들의정원
# 2496               온라인 라이브 클래스                 정강욱, 이연임 (지은이)      리얼러닝
# 2497           아빠와 딸의 주식 투자 레슨  대니얼 타운, 필 타운 (지은이), 김인정 (옮긴이)    에프엔미디어
# 2498                       페이크      로버트 기요사키 (지은이), 박슬라 (옮긴이)       민음인
# 2499               나는 오를 땅만 산다              김종율(옥탑방보보스) (지은이)    한국경제신문
#
#                                                   image
# 2495  https://image.aladin.co.kr/product/25232/50/co...
# 2496  https://image.aladin.co.kr/product/24946/65/co...
# 2497  https://image.aladin.co.kr/product/23481/71/co...
# 2498  https://image.aladin.co.kr/product/19692/30/co...
# 2499  https://image.aladin.co.kr/product/17546/61/co...

# %%
# csv 저장
business.to_csv('C:\\Users\\kim23\\data\\final\\business.csv',index=False,encoding ='utf-8-sig')

# %%
# 중복데이터 제거
business_remove = business.drop_duplicates('title',keep='first')
len(business_remove)
# Out:
# 796

# %%
# csv 저장
business_remove.to_csv('C:\\Users\\kim23\\data\\final\\business_remove.csv',index=False,encoding ='utf-8-sig')

# %% [markdown]
# ### 고전

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)','(원작)','(참고서)','(캐릭터)','(기획)','(구성)','(디자인)','(해설)']
book_list8 = []
image8 =[]
title8 = []

# %%
# 종합 도서 1~10 월
cnt = 0

for month in tqdm_notebook(range(1,11)):

    for page in range(1,6):
        
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=2105&Year=2020&Month='+str(month)+'&Week=3&page='+str(page)+'&cnt=1000&SortOrder=1'
        
        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
        
        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')

        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')
            image_ls = list[i].find_element_by_tag_name('img').get_attribute('src')
            image8.append(image_ls)
            title8.append(book_name_elems[i].get_text())

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j)| (file_format[7] in j) | (file_format[8] in j)|(file_format[9] in j)|(file_format[10] in j)|(file_format[11] in j)|(file_format[12] in j)|(file_format[13] in j):
                    book_list8.append(j)
                    cnt +=1
                    break
                    
        print('{}월 {}페이지 cnt = {}'.format(month, page, cnt))
        cnt = 0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# ...
# 1월 1페이지 cnt = 50
# 1월 2페이지 cnt = 50
# 1월 3페이지 cnt = 50
# 1월 4페이지 cnt = 50
# 1월 5페이지 cnt = 50
# 2월 1페이지 cnt = 50
# 2월 2페이지 cnt = 50
# 2월 3페이지 cnt = 50
# 2월 4페이지 cnt = 50
# 2월 5페이지 cnt = 50
# 3월 1페이지 cnt = 50
# 3월 2페이지 cnt = 50
# 3월 3페이지 cnt = 50
# 3월 4페이지 cnt = 50
# 3월 5페이지 cnt = 50
# 4월 1페이지 cnt = 50
# 4월 2페이지 cnt = 50
# 4월 3페이지 cnt = 50
# 4월 4페이지 cnt = 50
# 4월 5페이지 cnt = 50
# 5월 1페이지 cnt = 50
# 5월 2페이지 cnt = 50
# 5월 3페이지 cnt = 50
# 5월 4페이지 cnt = 50
# 5월 5페이지 cnt = 50
# 6월 1페이지 cnt = 50
# 6월 2페이지 cnt = 50
# 6월 3페이지 cnt = 50
# 6월 4페이지 cnt = 50
# 6월 5페이지 cnt = 50
# 7월 1페이지 cnt = 50
# 7월 2페이지 cnt = 50
# 7월 3페이지 cnt = 50
# 7월 4페이지 cnt = 50
# 7월 5페이지 cnt = 50
# 8월 1페이지 cnt = 50
# 8월 2페이지 cnt = 50
# 8월 3페이지 cnt = 50
# 8월 4페이지 cnt = 50
# ...

# %%
print(len(title8))
print(len(image8))
# Out:
# 2500
# 2500

# %%
# 작가, 출판사 가져오기

split_booklist8=[]
author8 = []
publisher8 =[]

for s in range(len(book_list8)):
    input = book_list8[s].split('|')
    split_booklist8.append(input)

    author8.append(split_booklist8[s][0])
    publisher8.append(split_booklist8[s][1])

# %%
# 확인
print(split_booklist8[0:5])
print(len(split_booklist8))
print()
print(author8[0:5])
print(len(author8))
print()
print(publisher8[0:5])
print(len(publisher8))
# Out:
# [['헤르만 헤세 (지은이), 이순학 (옮긴이) ', ' 더스토리 ', ' 2017년 10월'], ['헤르만 헤세 (지은이), 전영애 (옮긴이) ', ' 민음사 ', ' 2000년 12월'], ['헤르만 헤세 (지은이), 안인희 (옮긴이) ', ' 문학동네 ', ' 2020년 1월'], ['올더스 헉슬리 (지은이), 안정효 (옮긴이) ', ' (주)태일소담출판사 ', ' 2015년 6월'], ['루이자 메이 올콧 (지은이), 강미경 (옮긴이) ', ' 알에이치코리아(RHK) ', ' 2020년 2월']]
# 2500
#
# ['헤르만 헤세 (지은이), 이순학 (옮긴이) ', '헤르만 헤세 (지은이), 전영애 (옮긴이) ', '헤르만 헤세 (지은이), 안인희 (옮긴이) ', '올더스 헉슬리 (지은이), 안정효 (옮긴이) ', '루이자 메이 올콧 (지은이), 강미경 (옮긴이) ']
# 2500
#
# [' 더스토리 ', ' 민음사 ', ' 문학동네 ', ' (주)태일소담출판사 ', ' 알에이치코리아(RHK) ']
# 2500

# %%
# 데이터 프레임 만들기 
import pandas as pd
import pandas as np

classics = pd.DataFrame({'title' : title8,
                     'author' : author8,
                     'publisher' : publisher8,
                    'image' : image8})

# %%
classics.tail()
# Out:
#                      title                            author publisher  \
# 2495             국가·정체(政體)             플라톤 (지은이), 박종현 (옮긴이)       서광사
# 2496               고문진보 전집    황견 (엮은이), 이장우, 우재호, 장세후 (옮긴이)     을유문화사
# 2497                황야의 이리          헤르만 헤세 (지은이), 권혁준 (옮긴이)     을유문화사
# 2498                  부활 1  레프 니콜라예비치 톨스토이 (지은이), 연진희 (옮긴이)       민음사
# 2499  초판본 징비록 (패브릭 양장 에디션)             류성룡 (지은이), 김문정 (옮긴이)      더스토리
#
#                                                   image
# 2495  https://image.aladin.co.kr/product/1/68/cover1...
# 2496  https://image.aladin.co.kr/product/25302/51/co...
# 2497  https://image.aladin.co.kr/product/24682/62/co...
# 2498  https://image.aladin.co.kr/product/22587/29/co...
# 2499  https://image.aladin.co.kr/product/21014/46/co...

# %%
# csv 저장
classics.to_csv('C:\\Users\\kim23\\data\\final\\classics.csv',index=False,encoding ='utf-8-sig')

# %%
# 중복데이터 제거
classics_remove = classics.drop_duplicates('title',keep='first')
len(classics_remove)
# Out:
# 488

# %%
# csv 저장
classics_remove.to_csv('C:\\Users\\kim23\\data\\final\\classics_remove.csv',index=False,encoding ='utf-8-sig')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
file_format = ['(지은이)', '(옮긴이)', '(엮은이)','(글)','(그림)', '(편곡)', '(감수)','(원작)','(참고서)','(캐릭터)','(기획)','(구성)','(디자인)','(해설)']
book_listdd = []
imagedd =[]
titledd = []

# %%
# 종합 도서 1~10 월
cnt = 0

for month in tqdm_notebook(range(1,11)):

    for page in range(1,6):
        
        url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=MonthlyBest&BranchType=1&CID=2105&Year=2020&Month='+str(month)+'&Week=3&page='+str(page)+'&cnt=1000&SortOrder=1'
        
        driver.get(url)

        list = driver.find_elements_by_css_selector("div.ss_book_box > table > tbody > tr")
        
        req = requests.get(url)
        content = req.content

        soup = BeautifulSoup(content,'html.parser')
        book_name_elems = soup.select('a.bo3 b')

        for i in range(len(list)) :
            split_ls = list[i].text.split('\n')
            image_ls = list[i].find_element_by_tag_name('img').get_attribute('src')
            image8.append(image_ls)
            title8.append(book_name_elems[i].get_text())

            for j in split_ls :
                if (file_format[0] in j) | (file_format[1] in j) | (file_format[2] in j)|(file_format[3] in j)|(file_format[4] in j)|(file_format[5] in j) |(file_format[6] in j)| (file_format[7] in j) | (file_format[8] in j)|(file_format[9] in j)|(file_format[10] in j)|(file_format[11] in j)|(file_format[12] in j)|(file_format[13] in j):
                    book_list8.append(j)
                    cnt +=1
                    break
                    
        print('{}월 {}페이지 cnt = {}'.format(month, page, cnt))
        cnt = 0

# %%
# 교보문고 

from selenium import webdriver
from bs4 import BeautifulSoup

path = './driver/chromedriver.exe'
driver = webdriver.Chrome(path)

# %%
url = 'http://www.kyobobook.co.kr/product/detailViewKor.laf?ejkGb=KOR&mallGb=KOR&barcode=9791188331796&orderClick=LET&Kc='
driver.get(url)

# %%
list = driver.find_elements_by_css_selector("div.book_keyword >a")

# %%
list[5].text
# Out:
# '고기'

# %%
for i in range(len(list)):
    print(list[i].text)
# Out:
# 부자되는법
# 종잣돈
# 부자
# 경제철학
# 주라
# 고기
